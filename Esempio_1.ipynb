# %% [markdown]
# <a href="https://colab.research.google.com/github/matteogolfarelli/DataCentricAI/blob/main/Esempio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, , plot_tree
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np

#------------------------------------------------------------- Caricamento da file e creazione data frame
# Modificato l'URL per puntare al file CSV raw su GitHub
url = "https://raw.githubusercontent.com/matteogolfarelli/DataCentricAI/main/Iris.csv"
df = pd.read_csv(url)

#Caricamento da file nel PC
# Mostra il popup per caricare il file
# uploaded = files.upload()
# 'uploaded' è un dizionario: chiave = nome file, valore = contenuto
# Se il file si chiama "dati.csv":
#df = pd.read_csv("Iris.csv")

print(df.head()) # Modificato per visualizzare esplicitamente le prime 5 righe
print("Il dataset contiene ", len(df), "tuple")

#------------------------------------------------------------- Data preprocessing
target_col = "Species"

X = df.drop(columns=target_col)
y = df[target_col]
print(df.head)
print(X.head)
print(y.head)

#------------------------------------------------------------- Model training and testing con split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# Predizioni sul test set
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("Precision: ", precision_score(y_test, y_pred, average='macro'))
print("Recall: ", recall_score(y_test, y_pred, average='macro'))
print("F1-score: ", f1_score(y_test, y_pred, average='macro'))

#------------------------------------------------------------- Model training and testing con cross validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

scoring = ["accuracy", "precision_macro", "recall_macro", "f1_macro"]

clf = DecisionTreeClassifier(random_state=42)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

results = cross_validate(clf, X, y, cv=skf, scoring=scoring, return_train_score=True)
print(results)
print("Mean train accuracy:", results['test_accuracy'].mean())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# Il dataset contiene  150 tuple
# <bound method NDFrame.head of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]>
# <bound method NDFrame.head of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]>
# <bound method NDFrame.head of 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object>
# [[15  0  0]
#  [ 0 15  0]
#  [ 0  0 15]]
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# F1-score:  1.0
# {'fit_time': array([0.0028131 , 0.00276804, 0.00288892, 0.00279903, 0.00289869]), 'score_time': array([0.00796366, 0.00788569, 0.00779104, 0.00757289, 0.00798988]), 'test_accuracy': array([1., 1., 1., 1., 1.]), 'train_accuracy': array([1., 1., 1., 1., 1.]), 'test_precision_macro': array([1., 1., 1., 1., 1.]), 'train_precision_macro': array([1., 1., 1., 1., 1.]), 'test_recall_macro': array([1., 1., 1., 1., 1.]), 'train_recall_macro': array([1., 1., 1., 1., 1.]), 'test_f1_macro': array([1., 1., 1., 1., 1.]), 'train_f1_macro': array([1., 1., 1., 1., 1.])}
# Mean train accuracy: 1.0
